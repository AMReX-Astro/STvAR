# %%
import yt
import numpy as np

# %%
plot_num = 20
diag_num = 20
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2021-01-22 14:12:16,775 Parameters: current_time              = 0.0390625
# yt : [INFO     ] 2021-01-22 14:12:16,776 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-01-22 14:12:16,777 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-01-22 14:12:16,777 Parameters: domain_right_edge         = [20. 20.  1.]
# yt : [INFO     ] 2021-01-22 14:12:16,791 Parameters: current_time              = 0.0390625
# yt : [INFO     ] 2021-01-22 14:12:16,791 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-01-22 14:12:16,792 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-01-22 14:12:16,793 Parameters: domain_right_edge         = [20. 20.  1.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'Crap'), ('boxlib', 'PhiIm'), ('boxlib', 'PhiRe'), ('boxlib', 'PiPhiIm'), ('boxlib', 'PiPhiRe')]
# []

# %%
var = 'PhiRe'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids()
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'PhiIm'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'PiPhiRe'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids()
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'PiPhiIm'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'Crap'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-01-22 14:13:08,371 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,372 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,373 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,374 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,375 Making a fixed resolution buffer of (('boxlib', 'PhiRe')) 800 by 800
# yt : [INFO     ] 2021-01-22 14:13:08,468 Making a fixed resolution buffer of (('boxlib', 'PhiRe')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-22 14:13:08,854 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,854 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,855 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,856 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:08,856 Making a fixed resolution buffer of (('boxlib', 'PhiIm')) 800 by 800
# yt : [INFO     ] 2021-01-22 14:13:08,948 Making a fixed resolution buffer of (('boxlib', 'PhiIm')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-22 14:13:09,307 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,308 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,309 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,309 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,310 Making a fixed resolution buffer of (('boxlib', 'PiPhiRe')) 800 by 800
# yt : [WARNING  ] 2021-01-22 14:13:09,331 Plot image for field ('boxlib', 'PiPhiRe') has both positive and negative values. Min = -0.474341, Max = 0.474341.
# yt : [WARNING  ] 2021-01-22 14:13:09,332 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-01-22 14:13:09,444 Making a fixed resolution buffer of (('boxlib', 'PiPhiRe')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-22 14:13:09,754 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,754 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,755 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,756 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:09,757 Making a fixed resolution buffer of (('boxlib', 'PiPhiIm')) 800 by 800
# yt : [WARNING  ] 2021-01-22 14:13:09,777 Plot image for field ('boxlib', 'PiPhiIm') has both positive and negative values. Min = -0.305679, Max = 0.305679.
# yt : [WARNING  ] 2021-01-22 14:13:09,778 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-01-22 14:13:09,888 Making a fixed resolution buffer of (('boxlib', 'PiPhiIm')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-22 14:13:10,270 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:10,271 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:10,271 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:10,272 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-22 14:13:10,273 Making a fixed resolution buffer of (('boxlib', 'Crap')) 800 by 800
# yt : [WARNING  ] 2021-01-22 14:13:10,290 Plot image for field ('boxlib', 'Crap') has zero dynamic range. Min = Max = 0.000000.
# yt : [WARNING  ] 2021-01-22 14:13:10,290 Switching to linear colorbar scaling.
# yt : [INFO     ] 2021-01-22 14:13:10,366 Making a fixed resolution buffer of (('boxlib', 'Crap')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
## var = 'Ksclr'
for i in range(0,110):
    ident = list(str(int(i)+10000))
    ident[0] = '0'
    diagname = "diag00"+"".join(ident)
    ddiag = yt.load(diagname)
    s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_grids()
    #s.annotate_cell_edges()
    s.zoom(4)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    dst = "img"+"".join(ident2)+".png"
    print(diagname)
    print(dst)
    s.save(dst)

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg[var][:,:,:].d

# %%
H[133, 128, 128]
# Out:
# 0.071675151265037831

# %%
H[64, 64, 64]
# Out:
# -255.25140883924439

# %%
H[0, 0, 0]
# Out:
# 0.020330312720008004
