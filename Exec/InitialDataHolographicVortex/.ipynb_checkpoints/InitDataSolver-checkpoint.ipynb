# %%
import yt
import numpy as np

# %%
plot_num = 0
diag_num = 0
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2020-12-24 09:02:49,260 Parameters: current_time              = 0.0
# yt : [INFO     ] 2020-12-24 09:02:49,261 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2020-12-24 09:02:49,261 Parameters: domain_left_edge          = [-10. -10.   0.]
# yt : [INFO     ] 2020-12-24 09:02:49,262 Parameters: domain_right_edge         = [10. 10.  1.]
# yt : [INFO     ] 2020-12-24 09:02:49,277 Parameters: current_time              = 0.0
# yt : [INFO     ] 2020-12-24 09:02:49,278 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2020-12-24 09:02:49,278 Parameters: domain_left_edge          = [-10. -10.   0.]
# yt : [INFO     ] 2020-12-24 09:02:49,279 Parameters: domain_right_edge         = [10. 10.  1.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'Q6')]
# []

# %%
var = 'Q6'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0.9])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2020-12-24 09:04:38,734 xlim = -10.000000 10.000000
# yt : [INFO     ] 2020-12-24 09:04:38,735 ylim = -10.000000 10.000000
# yt : [INFO     ] 2020-12-24 09:04:38,736 xlim = -10.000000 10.000000
# yt : [INFO     ] 2020-12-24 09:04:38,736 ylim = -10.000000 10.000000
# yt : [INFO     ] 2020-12-24 09:04:38,737 Making a fixed resolution buffer of (('boxlib', 'Q6')) 800 by 800
# yt : [INFO     ] 2020-12-24 09:04:38,822 Making a fixed resolution buffer of (('boxlib', 'Q6')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
var = 'phi'
for i in range(301):
    ident = list(str(int(5*i)+10000))
    ident[0] = '0'
    filename = "plt00"+"".join(ident)
    ds = yt.load(filename)
    s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_cell_edges()
    s.zoom(2)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    s.save("img"+"".join(ident2)+".png")

# %%
cg = dplot.covering_grid(left_edge=dplot.domain_left_edge, dims=dplot.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["Q6"][:,:,:].d

# %%
H[0, 0, 0]
# Out:
# 2.0276912614961664

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
