# %%
import yt
import numpy as np

# %%
filename = "plt0000040"

# %%
ds = yt.load(filename)
# Out:
# yt : [INFO     ] 2020-04-28 14:58:39,547 Parameters: current_time              = 11.71875
# yt : [INFO     ] 2020-04-28 14:58:39,547 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2020-04-28 14:58:39,548 Parameters: domain_left_edge          = [-75. -75. -75.]
# yt : [INFO     ] 2020-04-28 14:58:39,549 Parameters: domain_right_edge         = [ 75.  75.  75.]

# %%
print(ds.field_list)
# Out:
# [('boxlib', 'AtildeLL00'), ('boxlib', 'AtildeLL01'), ('boxlib', 'AtildeLL02'), ('boxlib', 'AtildeLL11'), ('boxlib', 'AtildeLL12'), ('boxlib', 'AtildeLL22'), ('boxlib', 'BU0'), ('boxlib', 'BU1'), ('boxlib', 'BU2'), ('boxlib', 'GamtildeU0'), ('boxlib', 'GamtildeU1'), ('boxlib', 'GamtildeU2'), ('boxlib', 'Khat'), ('boxlib', 'alpha'), ('boxlib', 'betaU0'), ('boxlib', 'betaU1'), ('boxlib', 'betaU2'), ('boxlib', 'gamtildeLL00'), ('boxlib', 'gamtildeLL01'), ('boxlib', 'gamtildeLL02'), ('boxlib', 'gamtildeLL11'), ('boxlib', 'gamtildeLL12'), ('boxlib', 'gamtildeLL22'), ('boxlib', 'phi'), ('boxlib', 'theta')]

# %%
var = 'alpha'
s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2020-04-28 14:58:40,601 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-04-28 14:58:40,602 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-04-28 14:58:40,604 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-04-28 14:58:40,605 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-04-28 14:58:40,607 Making a fixed resolution buffer of (('boxlib', 'alpha')) 800 by 800
# yt : [INFO     ] 2020-04-28 14:58:40,741 Making a fixed resolution buffer of (('boxlib', 'alpha')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
s.save("phi_t400.pdf")

# %%
var = 'phi'
for i in range(301):
    ident = list(str(int(5*i)+10000))
    ident[0] = '0'
    filename = "plt00"+"".join(ident)
    ds = yt.load(filename)
    s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_cell_edges()
    s.zoom(2)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    s.save("img"+"".join(ident2)+".png")

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["H"][:,:,:].d

# %%
H[63, 63, 63]
# Out:
# -255.25140883924465

# %%
H[64, 64, 64]
# Out:
# -255.25140883924439

# %%
H[0, 0, 0]
# Out:
# 0.020330312720008004
