# %%
import yt
import numpy as np

# %%
filename = "plt0000100"

# %%
ds = yt.load(filename)
# Out:
# yt : [INFO     ] 2020-05-11 20:18:31,130 Parameters: current_time              = 5.859375
# yt : [INFO     ] 2020-05-11 20:18:31,131 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2020-05-11 20:18:31,132 Parameters: domain_left_edge          = [-75. -75. -75.]
# yt : [INFO     ] 2020-05-11 20:18:31,132 Parameters: domain_right_edge         = [ 75.  75.  75.]

# %%
print(ds.field_list)
# Out:
# [('boxlib', 'u')]

# %%
var = 'u'
s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2020-05-11 20:18:33,809 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-11 20:18:33,810 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-11 20:18:33,812 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-11 20:18:33,813 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-11 20:18:33,819 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [INFO     ] 2020-05-11 20:18:39,258 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
var = 'u'
s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2020-05-06 13:55:18,089 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,089 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,094 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [INFO     ] 2020-05-06 13:55:18,187 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
s.save("phi_t400.pdf")
# Out:
# yt : [INFO     ] 2020-05-05 15:32:40,763 Saving plot phi_t400.pdf
# ['phi_t400.pdf']

# %%
var = 'phi'
for i in range(301):
    ident = list(str(int(5*i)+10000))
    ident[0] = '0'
    filename = "plt00"+"".join(ident)
    ds = yt.load(filename)
    s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_cell_edges()
    s.zoom(2)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    s.save("img"+"".join(ident2)+".png")

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
