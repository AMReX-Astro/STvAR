# %%
import yt
import numpy as np

# %%
plot_num = 17
diag_num = 17
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2021-03-03 14:18:13,730 Parameters: current_time              = 3.3203125
# yt : [INFO     ] 2021-03-03 14:18:13,730 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-03-03 14:18:13,731 Parameters: domain_left_edge          = [-50. -50. -50.]
# yt : [INFO     ] 2021-03-03 14:18:13,732 Parameters: domain_right_edge         = [50. 50. 50.]
# yt : [INFO     ] 2021-03-03 14:18:13,748 Parameters: current_time              = 3.3203125
# yt : [INFO     ] 2021-03-03 14:18:13,748 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-03-03 14:18:13,749 Parameters: domain_left_edge          = [-50. -50. -50.]
# yt : [INFO     ] 2021-03-03 14:18:13,749 Parameters: domain_right_edge         = [50. 50. 50.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'AtildeLL00'), ('boxlib', 'AtildeLL01'), ('boxlib', 'AtildeLL02'), ('boxlib', 'AtildeLL11'), ('boxlib', 'AtildeLL12'), ('boxlib', 'AtildeLL22'), ('boxlib', 'GamtildeU0'), ('boxlib', 'GamtildeU1'), ('boxlib', 'GamtildeU2'), ('boxlib', 'Khat'), ('boxlib', 'alpha'), ('boxlib', 'betaU0'), ('boxlib', 'betaU1'), ('boxlib', 'betaU2'), ('boxlib', 'chi'), ('boxlib', 'gamtildeLL00'), ('boxlib', 'gamtildeLL01'), ('boxlib', 'gamtildeLL02'), ('boxlib', 'gamtildeLL11'), ('boxlib', 'gamtildeLL12'), ('boxlib', 'gamtildeLL22'), ('boxlib', 'theta')]
# [('boxlib', 'C'), ('boxlib', 'H'), ('boxlib', 'Ksclr'), ('boxlib', 'ML0'), ('boxlib', 'ML1'), ('boxlib', 'ML2')]

# %%
var = 'AtildeLL11'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids()
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(5)
s.show()

var = 'chi'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(3)
s.show()

var = 'Khat'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(3)
s.show()
# Out:
# yt : [INFO     ] 2021-03-03 14:39:27,336 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:27,336 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:27,337 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:27,339 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:27,340 Making a fixed resolution buffer of (('boxlib', 'AtildeLL11')) 800 by 800
# yt : [WARNING  ] 2021-03-03 14:39:27,376 Plot image for field ('boxlib', 'AtildeLL11') has both positive and negative values. Min = -1.015874, Max = 0.410659.
# yt : [WARNING  ] 2021-03-03 14:39:27,377 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-03-03 14:39:27,505 Making a fixed resolution buffer of (('boxlib', 'AtildeLL11')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-03-03 14:39:28,099 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,100 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,101 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,102 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,103 Making a fixed resolution buffer of (('boxlib', 'chi')) 800 by 800
# yt : [INFO     ] 2021-03-03 14:39:28,223 Making a fixed resolution buffer of (('boxlib', 'chi')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-03-03 14:39:28,552 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,553 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,554 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,555 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-03-03 14:39:28,557 Making a fixed resolution buffer of (('boxlib', 'Khat')) 800 by 800
# yt : [WARNING  ] 2021-03-03 14:39:28,584 Plot image for field ('boxlib', 'Khat') has both positive and negative values. Min = -0.022346, Max = 0.204574.
# yt : [WARNING  ] 2021-03-03 14:39:28,585 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-03-03 14:39:28,794 Making a fixed resolution buffer of (('boxlib', 'Khat')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
## var = 'Ksclr'
for i in range(0,110):
    ident = list(str(int(i)+10000))
    ident[0] = '0'
    diagname = "diag00"+"".join(ident)
    ddiag = yt.load(diagname)
    s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_grids()
    #s.annotate_cell_edges()
    s.zoom(4)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    dst = "img"+"".join(ident2)+".png"
    print(diagname)
    print(dst)
    s.save(dst)

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg[var][:,:,:].d

# %%
H[133, 128, 128]
# Out:
# 0.071675151265037831

# %%
H[64, 64, 64]
# Out:
# -255.25140883924439

# %%
H[0, 0, 0]
# Out:
# 0.020330312720008004
