# %%
import yt
import numpy as np

# %%
plot_num = 20
diag_num = 20
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2021-01-04 14:50:37,427 Parameters: current_time              = 0.046874999999999986
# yt : [INFO     ] 2021-01-04 14:50:37,427 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-01-04 14:50:37,428 Parameters: domain_left_edge          = [-50. -50. -50.]
# yt : [INFO     ] 2021-01-04 14:50:37,429 Parameters: domain_right_edge         = [50. 50. 50.]
# yt : [INFO     ] 2021-01-04 14:50:37,446 Parameters: current_time              = 0.046874999999999986
# yt : [INFO     ] 2021-01-04 14:50:37,447 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-01-04 14:50:37,447 Parameters: domain_left_edge          = [-50. -50. -50.]
# yt : [INFO     ] 2021-01-04 14:50:37,448 Parameters: domain_right_edge         = [50. 50. 50.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'u')]
# [('boxlib', 'alpha'), ('boxlib', 'chi')]

# %%
var = 'u'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(2)
s.show()

var = 'alpha'
s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(2)
s.show()
# Out:
# yt : [INFO     ] 2021-01-04 14:50:43,813 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:43,814 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:43,815 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:43,816 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:43,821 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [INFO     ] 2021-01-04 14:50:44,351 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-04 14:50:44,795 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:44,796 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:44,797 xlim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:44,797 ylim = -50.000000 50.000000
# yt : [INFO     ] 2021-01-04 14:50:44,798 Making a fixed resolution buffer of (('boxlib', 'alpha')) 800 by 800
# yt : [INFO     ] 2021-01-04 14:50:44,907 Making a fixed resolution buffer of (('boxlib', 'alpha')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
var = 'u'
s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2020-05-06 13:55:18,089 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,089 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,094 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [INFO     ] 2020-05-06 13:55:18,187 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
s.save("phi_t400.pdf")
# Out:
# yt : [INFO     ] 2020-05-05 15:32:40,763 Saving plot phi_t400.pdf
# ['phi_t400.pdf']

# %%
var = 'phi'
for i in range(301):
    ident = list(str(int(5*i)+10000))
    ident[0] = '0'
    filename = "plt00"+"".join(ident)
    ds = yt.load(filename)
    s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_cell_edges()
    s.zoom(2)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    s.save("img"+"".join(ident2)+".png")

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
