# %%
import yt
import numpy as np

# %%
plot_num = 0
diag_num = 0
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2021-01-25 16:27:30,354 Parameters: current_time              = 0.0
# yt : [INFO     ] 2021-01-25 16:27:30,355 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2021-01-25 16:27:30,355 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-01-25 16:27:30,356 Parameters: domain_right_edge         = [20. 20.  1.]
# yt : [INFO     ] 2021-01-25 16:27:30,368 Parameters: current_time              = 0.0
# yt : [INFO     ] 2021-01-25 16:27:30,368 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2021-01-25 16:27:30,369 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-01-25 16:27:30,369 Parameters: domain_right_edge         = [20. 20.  1.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'Q6')]
# []

# %%
var = 'Q6'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'Q7'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'dotQ6'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'dotQ7'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-01-25 16:27:31,332 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-25 16:27:31,333 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-25 16:27:31,335 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-25 16:27:31,336 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-25 16:27:31,338 Making a fixed resolution buffer of (('boxlib', 'Q6')) 800 by 800
# yt : [INFO     ] 2021-01-25 16:27:31,503 Making a fixed resolution buffer of (('boxlib', 'Q6')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# <ipython-input-10-9b4630aeacae> in <module>
#      11
#      12 var = 'Q7'
# ---> 13 s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
#      14 s.set_log(('boxlib', var), False)
#      15 s.set_xlabel('x - Axis')
#
# ~/.local/lib/python3.5/site-packages/yt/visualization/plot_window.py in SlicePlot(ds, normal, fields, axis, *args, **kwargs)
#    1984             del kwargs['north_vector']
#    1985
# -> 1986         return AxisAlignedSlicePlot(ds, normal, fields, *args, **kwargs)
#    1987
#    1988 def plot_2d(ds, fields, center='c', width=None, axes_unit=None,
#
# ~/.local/lib/python3.5/site-packages/yt/visualization/plot_window.py in __init__(self, ds, axis, fields, center, width, axes_unit, origin, right_handed, fontsize, field_parameters, window_size, aspect, data_source)
#    1280             slc = ds.slice(axis, center[axis], field_parameters=field_parameters,
#    1281                            center=center, data_source=data_source)
# -> 1282             slc.get_data(fields)
#    1283         validate_mesh_fields(slc, fields)
#    1284         PWViewerMPL.__init__(self, slc, bounds, origin=origin,
#
# ~/.local/lib/python3.5/site-packages/yt/data_objects/data_containers.py in get_data(self, fields)
#    1509         nfields = []
#    1510         apply_fields = defaultdict(list)
# -> 1511         for field in self._determine_fields(fields):
#    1512             # We need to create the field on the raw particle types
#    1513             # for particles types (when the field is not directly
#
# ~/.local/lib/python3.5/site-packages/yt/data_objects/data_containers.py in _determine_fields(self, fields)
#    1358                     raise YTFieldNotParseable(field)
#    1359                 ftype, fname = field
# -> 1360                 finfo = self.ds._get_field_info(ftype, fname)
#    1361             elif isinstance(field, DerivedField):
#    1362                 ftype, fname = field.name
#
# ~/.local/lib/python3.5/site-packages/yt/data_objects/static_output.py in _get_field_info(self, ftype, fname)
#     737                     self._last_finfo = self.field_info[(ftype, fname)]
#     738                     return self._last_finfo
# --> 739         raise YTFieldNotFound((ftype, fname), self)
#     740
#     741     def _setup_classes(self):
#
# YTFieldNotFound: Could not find field '('boxlib', 'Q7')' in plt0000000.

# %%
var = 'u'
s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2020-05-06 13:55:18,089 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,089 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,094 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [INFO     ] 2020-05-06 13:55:18,187 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
s.save("phi_t400.pdf")
# Out:
# yt : [INFO     ] 2020-05-05 15:32:40,763 Saving plot phi_t400.pdf
# ['phi_t400.pdf']

# %%
var = 'phi'
for i in range(301):
    ident = list(str(int(5*i)+10000))
    ident[0] = '0'
    filename = "plt00"+"".join(ident)
    ds = yt.load(filename)
    s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_cell_edges()
    s.zoom(2)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    s.save("img"+"".join(ident2)+".png")

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
