# %%
import yt
import numpy as np

# %%
plot_num = 0
diag_num = 0
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2021-01-26 10:25:43,146 Parameters: current_time              = 0.0
# yt : [INFO     ] 2021-01-26 10:25:43,146 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-01-26 10:25:43,147 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-01-26 10:25:43,148 Parameters: domain_right_edge         = [20. 20.  1.]
# yt : [INFO     ] 2021-01-26 10:25:43,165 Parameters: current_time              = 0.0
# yt : [INFO     ] 2021-01-26 10:25:43,165 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-01-26 10:25:43,165 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-01-26 10:25:43,166 Parameters: domain_right_edge         = [20. 20.  1.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'Q6'), ('boxlib', 'Q7'), ('boxlib', 'dotQ6'), ('boxlib', 'dotQ7')]
# []

# %%
var = 'Q6'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'Q7'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'dotQ6'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'dotQ7'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-01-26 10:25:44,565 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:44,566 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:44,567 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:44,567 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:44,568 Making a fixed resolution buffer of (('boxlib', 'Q6')) 800 by 800
# yt : [INFO     ] 2021-01-26 10:25:44,661 Making a fixed resolution buffer of (('boxlib', 'Q6')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-26 10:25:45,021 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,021 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,022 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,023 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,024 Making a fixed resolution buffer of (('boxlib', 'Q7')) 800 by 800
# yt : [INFO     ] 2021-01-26 10:25:45,115 Making a fixed resolution buffer of (('boxlib', 'Q7')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-26 10:25:45,428 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,428 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,429 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,430 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,431 Making a fixed resolution buffer of (('boxlib', 'dotQ6')) 800 by 800
# yt : [WARNING  ] 2021-01-26 10:25:45,452 Plot image for field ('boxlib', 'dotQ6') has both positive and negative values. Min = -0.239806, Max = 0.239806.
# yt : [WARNING  ] 2021-01-26 10:25:45,453 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-01-26 10:25:45,563 Making a fixed resolution buffer of (('boxlib', 'dotQ6')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-01-26 10:25:45,937 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,937 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,938 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,939 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-01-26 10:25:45,939 Making a fixed resolution buffer of (('boxlib', 'dotQ7')) 800 by 800
# yt : [WARNING  ] 2021-01-26 10:25:45,959 Plot image for field ('boxlib', 'dotQ7') has both positive and negative values. Min = -0.245079, Max = 0.245079.
# yt : [WARNING  ] 2021-01-26 10:25:45,960 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-01-26 10:25:46,069 Making a fixed resolution buffer of (('boxlib', 'dotQ7')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
var = 'u'
s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2020-05-06 13:55:18,089 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,089 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 xlim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,092 ylim = -75.000000 75.000000
# yt : [INFO     ] 2020-05-06 13:55:18,094 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [INFO     ] 2020-05-06 13:55:18,187 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
s.save("phi_t400.pdf")
# Out:
# yt : [INFO     ] 2020-05-05 15:32:40,763 Saving plot phi_t400.pdf
# ['phi_t400.pdf']

# %%
var = 'phi'
for i in range(301):
    ident = list(str(int(5*i)+10000))
    ident[0] = '0'
    filename = "plt00"+"".join(ident)
    ds = yt.load(filename)
    s = yt.SlicePlot(ds, 'z', ('boxlib', var), origin='native', center = [0,0,0])
    s.set_log(('boxlib', var), False)
    s.set_xlabel('x - Axis')
    s.set_ylabel('y - Axis')
    s.hide_colorbar()
    #s.annotate_cell_edges()
    s.zoom(2)
    
    ident2 = list(str(i+10000))
    ident2[0] = '0'
    s.save("img"+"".join(ident2)+".png")

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
